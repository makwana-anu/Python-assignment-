# %% [markdown]
# # Q1 write a python program to calculate the length of a string

# %%
s=input ("Enter The String ")
# Out:
# Enter The String Today is the first day of new year

# %%
print(s)
# Out:
# Today is the first day of new year

# %% [markdown]
# # Length of The string

# %%
l1=len(s)

# %%
print ("Length of The String:",l1)
# Out:
# Length of The String: 35

# %% [markdown]
# #Q.2 Python Program to calculate the square root

# %%
import math

# %%
print ("The square root of 16 is",math.sqrt(16))#pass the decimal number
# Out:
# The square root of 16 is 4.0

# %% [markdown]
# #Q.3 Write the python program to convert temperature in celsius to temperature in Fahrenheit

# %%
celsius=25

# %%
Fahrenheit=celsius*9/5+32

# %%
print (Fahrenheit)
# Out:
# 77.0

# %% [markdown]
# #Q.4 Write a data type needed for given data.(10,4.5,2+6j)

# %%
num=10

# %%
type(num)
# Out:
# int

# %%
num=4.5

# %%
type(num)
# Out:
# float

# %%
num=2+6j

# %%
type(num)
# Out:
# complex
